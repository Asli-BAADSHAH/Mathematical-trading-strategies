# %%
#FOR INDICES

import yfinance as yf
import numpy as np
import statistics as st

tickers=["^gspc","^dji","^ixic","^nya","^xax"]  

def cum_return(arr1,arr2):    
    a=len(arr1)
    cr=(arr1[len(arr1)-1]-arr2[0])/arr2[0]
    return cr

def maxd(trough,peak):
    max=(trough-peak)/peak   
    return max

cumulative_return=[]            
volatility=[]        
sharpe_ratio=[]       
sortino_ratio=[]     
max_drawdown=[]       

for x in range(5):   
    neg=[]           

    df =yf.download(tickers[x],  start = "2010-01-01" , end = "2023-05-16")    
    adj_close,close,open=df['Adj Close'],df['Close'],df['Open']                
    cumulative_return.append(cum_return(close,open))                   
    
    adjClose=np.array(adj_close)
    opn=np.array(open)                
    diff=np.subtract(adjClose,opn)             
    difference=list(diff) 
    for y in range(len(difference)):    
        if difference[y]<0:           
            neg.append(difference[y])
            
    neg_stdev=st.stdev(neg)       
    stdev=st.stdev(difference)
    volatility.append(stdev*(np.sqrt(252)))   
    
    mean=st.mean(difference)
    sharpe_ratio.append(((mean*100)-7.07)/stdev)    
    
    sortino_ratio.append(((mean*100)-7.07)/neg_stdev)
    
    possible=[]
    for i in range(len(close)):
        for j in range(len(close)):
            if i<j and close[i]>=close[j]:
                possible.append((maxd(close[j],close[i]))*100)    #max drawdown in %
    mx=123456789            
    for x in range(len(possible)):
        if possible[x]<=mx:
            mx=possible[x]
    max_drawdown.append(mx)    

print(cumulative_return)
print(volatility)
print(sharpe_ratio)
print(sortino_ratio)
print(max_drawdown)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [2.704484817740733, 2.197161471457754, 4.389276735458964, 1.1325820826174178, 1.1990302334650391]
# [388.27725598282746, 3161.2697211727077, 1383.394901737888, 1714.7856641897038, 499.4971600797922]
# [1.6178756528144933, 1.9742998618845147, 1.00489035442846, 0.5138787742639299, 1.022431488665755]
# [1.9162281901926512, 2.391117319715567, 1.1344635109621997, 0.6009004076563742, 1.267018473376621]
# [-33.92496000265327, -37.086171369594325, -36.395279909120205, -38.11424952096922, -53.51163257586528]

# %%
#FOR EQUITIES

import yfinance as yf
import numpy as np
import statistics as st

tickers=["pltr","amzn","teva","amd","bac"]  

def cum_return(arr1,arr2):    
    a=len(arr1)
    cr=(arr1[len(arr1)-1]-arr2[0])/arr2[0]
    return cr

def maxd(trough,peak):
    max=(trough-peak)/peak   
    return max

cumulative_return=[]            
volatility=[]        
sharpe_ratio=[]       
sortino_ratio=[]     
max_drawdown=[]       

for x in range(5):   
    neg=[]           

    df =yf.download(tickers[x],  start = "2010-01-01" , end = "2023-05-16")    
    adj_close,close,open=df['Adj Close'],df['Close'],df['Open']                
    cumulative_return.append(cum_return(close,open))                   
    
    adjClose=np.array(adj_close)
    opn=np.array(open)                
    diff=np.subtract(adjClose,opn)             
    difference=list(diff) 
    for y in range(len(difference)):    
        if difference[y]<0:           
            neg.append(difference[y])
            
    neg_stdev=st.stdev(neg)       
    stdev=st.stdev(difference)
    volatility.append(stdev*(np.sqrt(252)))   
    
    mean=st.mean(difference)
    sharpe_ratio.append(((mean*100)-7.07)/stdev)    
    
    sortino_ratio.append(((mean*100)-7.07)/neg_stdev)
    
    possible=[]
    for i in range(len(close)):
        for j in range(len(close)):
            if i<j and close[i]>=close[j]:
                possible.append((maxd(close[j],close[i]))*100)    #max drawdown in %
    mx=123456789            
    for x in range(len(possible)):
        if possible[x]<=mx:
            mx=possible[x]
    max_drawdown.append(mx)    

print(cumulative_return)
print(volatility)
print(sharpe_ratio)
print(sortino_ratio)
print(max_drawdown)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [-0.04799995422363281, 15.322935331852063, -0.8586690033191208, 8.948927671644574, 0.8143044641595545]
# [12.859214850686486, 21.899892384762904, 52.261660576377736, 21.261573559206834, 13.0310137966951]
# [-11.739956396489886, -6.797146675770558, -93.1565000864379, -5.39807432410215, -252.96631284597694]
# [-17.574342141585795, -7.91860212724655, -96.17771054961462, -6.213485042832102, -272.7986722960393]
# [-84.61538461538461, -56.14526325328263, -91.44444465637207, -84.05511782383532, -74.38398414589847]

# %%
# Out:
# [*********************100%***********************]  5 of 5 completed
#                Adj Close
#                     ^DJI        ^GSPC         ^IXIC          ^NYA
# Date
# 2010-01-04  10583.959961  1132.989990   2308.419922   7326.740234  \
# 2010-01-05  10572.019531  1136.520020   2308.709961   7354.870117
# 2010-01-06  10573.679688  1137.140015   2301.090088   7377.700195
# 2010-01-07  10606.860352  1141.689941   2300.050049   7393.930176
# 2010-01-08  10618.190430  1144.979980   2317.169922   7425.350098
# ...                  ...          ...           ...           ...
# 2023-05-09  33561.808594  4119.169922  12179.549805  15352.809570
# 2023-05-10  33531.328125  4137.640137  12306.440430  15349.169922
# 2023-05-11  33309.511719  4130.620117  12328.509766  15263.070312
# 2023-05-12  33300.621094  4124.080078  12284.740234  15246.360352
# 2023-05-15  33348.601562  4136.279785  12365.209961  15322.559570
#
#                                 Close
# ...

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[78], line 15
#      13     for j in low:
#      14         if i<j:
# ---> 15             possible.append(maxd(low[j],high[i]))
#      18 mx=0
#      19 for x in possible:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
# ...

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 12
#      10 lw=np.array(low)
#      11 for x in lw:
# ---> 12     print(low[x])
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1007, in Series.__getitem__(self, key)
#    1004     return self._values[key]
#    1006 elif key_is_scalar:
# -> 1007     return self._get_value(key)
#    1009 if is_hashable(key):
#    1010     # Otherwise index.get_value will raise InvalidIndexError
#    1011     try:
#    1012         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:1116, in Series._get_value(self, label, takeable)
#    1113     return self._values[label]
# ...

# %%
# Out:
# [*********************100%***********************]  1 of 1 completed
# -0.3811424952096922
